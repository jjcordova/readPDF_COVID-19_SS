# %%
import pdftotext
import json
import re
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
def buildArrayCOVID(LISTA_COVID):
    CASO = LISTA_COVID[0]
    FECHA_LL = LISTA_COVID[-1]
    ESTADO = LISTA_COVID[1]    
    SEXO =  LISTA_COVID[2] 
    EDAD =  LISTA_COVID[3] 
    FECHA = LISTA_COVID[4]
    IDENTI =  LISTA_COVID[5]    
    PROCEDENCIA =LISTA_COVID[-2]
    if len(LISTA_COVID) == 8:
        ESTADO = LISTA_COVID[1]
        SEXO = LISTA_COVID[2]
        EDAD = LISTA_COVID[3]
        FECHA = LISTA_COVID[4]
        IDENTI = LISTA_COVID[5]  
        PROCEDENCIA = LISTA_COVID[6]
    elif LISTA_COVID[1]=='CIUDAD' or LISTA_COVID[1]=='SAN':
        ESTADO = "{0} {1} {2}".format(LISTA_COVID[1],LISTA_COVID[2],LISTA_COVID[3])
        SEXO = LISTA_COVID[4]
        EDAD = LISTA_COVID[5]
        FECHA = LISTA_COVID[6]
        IDENTI = LISTA_COVID[7]
    elif LISTA_COVID[1]=='QUINTANA' or LISTA_COVID[1]=='NUEVO':
        ESTADO = "{0} {1}".format(LISTA_COVID[1],LISTA_COVID[2])    
        SEXO = LISTA_COVID[3]
        EDAD = LISTA_COVID[4]
        FECHA = LISTA_COVID[5]
        IDENTI = LISTA_COVID[6]    
    elif LISTA_COVID[1]=='BAJA' and LISTA_COVID[3]=='SUR':
        ESTADO = "{0} {1} {2}".format(LISTA_COVID[1],LISTA_COVID[2],LISTA_COVID[3])    
        SEXO = LISTA_COVID[4]
        EDAD = LISTA_COVID[5]
        FECHA = LISTA_COVID[6]
        IDENTI = LISTA_COVID[7]   
    elif LISTA_COVID[1]=='BAJA' and LISTA_COVID[3]!='SUR':
        ESTADO = "{0} {1}".format(LISTA_COVID[1],LISTA_COVID[2])    
        SEXO = LISTA_COVID[3]
        EDAD = LISTA_COVID[4]
        FECHA = LISTA_COVID[5]
        IDENTI = LISTA_COVID[6]         
    elif LISTA_COVID[-2] =='Unidos' or LISTA_COVID[-2] =='Unido' or LISTA_COVID[-2]=='Zelanda':
        PROCEDENCIA = "{0} {1}".format(LISTA_COVID[-3],LISTA_COVID[-2])   
    file_json = {'NCaso':CASO,
                'Estado':ESTADO,
                'Sexo':SEXO,
                'Edad':EDAD,
                'FechaIniSintomas':FECHA,
                'Identificacion':IDENTI,
                 'Procedencia':PROCEDENCIA,
                 'FechaLlegadaMexico':FECHA_LL.strip(' \r')
                } 
    return file_json

# %%
URL_COVID_MX = "https://www.gob.mx/cms/uploads/attachment/file/541580/Tabla_casos_positivos_resultado_InDRE_2020.03.16.pdf"
f = urlopen(URL_COVID_MX)
pdf = pdftotext.PDF(f)
text_data= pdf[0].split('\n')
temp_data = [ s.lstrip() for s in text_data[8].split() if s !='']
temp_data = buildArrayCOVID(temp_data)
JSON_COVID_19_Mx = {"COVID_19_MX":[temp_data]} 
#print(JSON_COVID_19_Mx['COVID_19_MX'])

# %%
for i in range(9,53):
    temp_data = [ s.lstrip() for s in text_data[i].split() if s !='']
    JSON_COVID_19_Mx['COVID_19_MX'].append(buildArrayCOVID(temp_data))
#print(JSON_COVID_19_Mx['COVID_19_MX'])

# %%
for j in range(1,len(pdf)-1):
    text_data= pdf[j].split('\n')
    for i in range(0, len(text_data)):
        temp_data = [ s.lstrip() for s in text_data[i].split() if s !='']
        JSON_COVID_19_Mx['COVID_19_MX'].append(buildArrayCOVID(temp_data))
#print(JSON_COVID_19_Mx)
JSON_DATA = json.dumps(JSON_COVID_19_Mx).encode('utf8')

# %%
print(JSON_DATA)
# Out:
# b'{"COVID_19_MX": [{"NCaso": "1", "Estado": "CIUDAD DE M\\u00c9XICO", "Sexo": "M", "Edad": "35", "FechaIniSintomas": "22/02/2020", "Identificacion": "confirmado", "Procedencia": "Italia", "FechaLlegadaMexico": "22/02/2020"}, {"NCaso": "2", "Estado": "SINALOA", "Sexo": "M", "Edad": "41", "FechaIniSintomas": "22/02/2020", "Identificacion": "confirmado", "Procedencia": "Italia", "FechaLlegadaMexico": "21/02/2020"}, {"NCaso": "3", "Estado": "CIUDAD DE M\\u00c9XICO", "Sexo": "M", "Edad": "59", "FechaIniSintomas": "23/02/2020", "Identificacion": "confirmado", "Procedencia": "Italia", "FechaLlegadaMexico": "22/02/2020"}, {"NCaso": "4", "Estado": "COAHUILA", "Sexo": "F", "Edad": "20", "FechaIniSintomas": "27/02/2020", "Identificacion": "confirmado", "Procedencia": "Italia", "FechaLlegadaMexico": "25/02/2020"}, {"NCaso": "5", "Estado": "CHIAPAS", "Sexo": "F", "Edad": "18", "FechaIniSintomas": "25/02/2020", "Identificacion": "confirmado", "Procedencia": "Italia", "FechaLlegadaMexico": "25/02/2020"}, {"NCaso": "6", "Estado": "M\\u00c9XICO", "Sexo": "M", "Edad": "71", "FechaIniSintomas": "21/02/2020", "Identificacion": "confirmado", "Procedencia": "Italia", "FechaLlegadaMexico": "21/02/2020"}, {"NCaso": "7", "Estado": "CIUDAD DE M\\u00c9XICO", "Sexo": "M", "Edad": "46", "FechaIniSintomas": "29/02/2020", "Identificacion": "confirmado", "Procedencia": "Unidos", "FechaLlegadaMexico": "29/02/2020"}, {"NCaso": "8", "Estado": "QUERETARO", "Sexo": "M", "Edad": "43", "FechaIniSintomas": "09/03/2020", "Identificacion": "confirmado", "Procedencia": "Espa\\u00f1a", "FechaLlegadaMexico": "06/03/2020"}, {"NCaso": "9", "Estado": "CIUDAD DE M\\u00c9XICO", "Sexo": "M", "Edad": "41", "FechaIniSintomas": "07/03/2020", "Identificacion": "confirmado", "Procedencia": "Unidos", "FechaLlegadaMexico": "06/03/2020"}, {"NCaso": "10", "Estado": "CIUDAD DE M\\u00c9XICO", "Sexo": "F", "Edad": "30", "FechaIniSintomas": "07/03/2020", "Identificacion": "confirmado", "Procedencia": "Espa\\u00f1a", "FechaLlegadaMexico": "06/03/2020"}, {"NCaso": "11", "Estado": "M\\u00c9XICO", "Sexo": "F", "Edad": "64", "FechaIniSintomas": "02/03/2020", "Identificacion": "confirmado", "Procedencia": "Estados Unidos", "FechaLlegadaMexico": "29/02/2020"}, {"NCaso": "12", "Estado": "NUEVO LE\\u00d3N", "Sexo": "M", "Edad": "57", "FechaIniSintomas": "04/03/2020", "Identificacion": "confirmado", "Procedencia": "Alemania", "FechaLlegadaMexico": "03/03/2020"}, {"NCaso": "13", "Estado": "M\\u00c9XICO", "Sexo": "F", "Edad": "55", "FechaIniSintomas": "09/03/2020", "Identificacion": "confirmado", "Procedencia": "Espa\\u00f1a", "FechaLlegadaMexico": "09/03/2020"}, {"NCaso": "14", "Estado": "DURANGO", "Sexo": "M", "Edad": "58", "FechaIniSintomas": "06/03/2020", "Identificacion": "confirmado", "Procedencia": "Espa\\u00f1a", "FechaLlegadaMexico": "28/02/2020"}, {"NCaso": "15", "Estado": "QUERETARO", "Sexo": "F", "Edad": "65", "FechaIniSintomas": "10/03/2020", "Identificacion": "confirmado", "Procedencia": "Contacto", "FechaLlegadaMexico": "NA"}, {"NCaso": "16", "Estado": "QUERETARO", "Sexo": "M", "Edad": "42", "FechaIniSintomas": "05/03/2020", "Identificacion": "confirmado", "Procedencia": "Italia", "FechaLlegadaMexico": "05/03/2020"}, {"NCaso": "17", "Estado": "CIUDAD DE M\\u00c9XICO", "Sexo": "M", "Edad": "48", "FechaIniSintomas": "10/03/2020", "Identificacion": "confirmado", "Procedencia": "Espa\\u00f1a", "FechaLlegadaMexico": "09/03/2020"}, {"NCaso": "18", "Estado": "CIUDAD DE M\\u00c9XICO", "Sexo": "M", "Edad": "38", "FechaIniSintomas": "10/03/2020", "Identificacion": "confirmado", "Procedencia": "Espa\\u00f1a", "FechaLlegadaMexico": "09/03/2020"}, {"NCaso": "19", "Estado": "QUERETARO", "Sexo": "F", "Edad": "43", "FechaIniSintomas": "11/03/2020", "Identificacion": "confirmado", "Procedencia": "Contacto", "FechaLlegadaMexico": "NA"}, {"NCaso": "20", "Estado": "PUEBLA", "Sexo": "M", "Edad": "31", "FechaIniSintomas": "05/03/2020", "Identificacion": "confirmado", "Procedencia": "Espa\\u00f1a", "FechaLleg ...
